# %%
YELP_CONSUMER_KEY = "mxTA2-C2hPWM3olLxWIglQ"
YELP_CONSUMER_SECRET = "LLXsp0F_gjNkHCFz1xwXDo4Yhuk"
YELP_TOKEN = "0pSLzELxRIVZPRPuyL8hXbG3KAEmeGHg"
YELP_SECRET_TOKEN = "ifsD5fkpwq-tMQ1eYLYo-cnTTT0"
from requests_oauthlib import OAuth1Session

# %%
yelp = OAuth1Session(client_key=YELP_CONSUMER_KEY,
              client_secret=YELP_CONSUMER_SECRET,
              resource_owner_key=YELP_TOKEN,
              resource_owner_secret=YELP_SECRET_TOKEN,
              callback_uri="https://anewhome.com")

# %%
res = yelp.get("http://api.yelp.com/v2/search?location=Wellington+New+Zealand&limit=20&category_filter={}".format(CINEMAS_CAT))

# %%
import json
data = json.loads(res.text)

# %%
CATEGORIES = [
    CINEMAS_CAT,
    HEALTH_MEDICAL_CAT,
    
]
for cat in CATEGORIES:
    res = yelp.get("http://api.yelp.com/v2/search?location=Wellington+New+Zealand&limit=20&category_filter={}".format(cat))
    f = open("wellington_{}.json".format(cat.lower()), "w")
    for b in data['businesses']:
        f.write(json.dumps(b) + '\n')

# %%
import string
import re
whitelist = string.letters + string.digits + ' '
new_s = ''.join(c for c in one if c in whitelist)
f = open("categories")
for line in f.readlines():
    name, code = re.search(r'(.*) \((\w*)', line).groups()
    name = '_'.join(''.join(c.upper() for c in name if c in whitelist).split())
    print("{}_CAT = '{}'".format(name, code))
# Out:
# ARTS_ENTERTAINMENT_CAT = 'arts'
# ARCADE_GAMES_CAT = 'arcades'
# ARENA_STADIUMS_CAT = 'stadiumsarenas'
# ART_GALLERIES_CAT = 'galleries'
# BINGO_HALLS_CAT = 'bingo'
# BOOKMAKERS_CAT = 'bookmakers'
# BOTANICAL_GARDENS_CAT = 'gardens'
# CABARETS_CAT = 'cabaret'
# CASINOS_CAT = 'casinos'
# CASTLES_CAT = 'castles'
# CHOIRS_CAT = 'choirs'
# CINEMAS_CAT = 'movietheaters'
# COUNTRY_CLUBS_CAT = 'countryclubs'
# CULTURAL_CENTRE_CAT = 'culturalcentre'
# FESTIVALS_CAT = 'festivals'
# CHRISTMAS_MARKETS_CAT = 'xmasmarkets'
# FUN_FAIRS_CAT = 'funfair'
# GENERAL_FESTIVALS_CAT = 'generalfestivals'
# TRADE_FAIRS_CAT = 'tradefairs'
# JAZZ_BLUES_CAT = 'jazzandblues'
# MAH_JONG_HALLS_CAT = 'mahjong'
# MARCHING_BANDS_CAT = 'marchingbands'
# MUSEUMS_CAT = 'museums'
# MUSIC_VENUES_CAT = 'musicvenues'
# OBSERVATORIES_CAT = 'observatories'
# OPERAS_CAT = 'opera'
# PACHINKO_CAT = 'pachinko'
# PAINT_SIP_CAT = 'paintandsip'
# PLANETARIUM_CAT = 'planetarium'
# PROFESSIONAL_SPORTS_TEAMS_CAT = 'sportsteams'
# ...

# %%
ARTS_ENTERTAINMENT_CAT = 'arts'
ARCADE_GAMES_CAT = 'arcades'
ARENA_STADIUMS_CAT = 'stadiumsarenas'
ART_GALLERIES_CAT = 'galleries'
BINGO_HALLS_CAT = 'bingo'
BOOKMAKERS_CAT = 'bookmakers'
BOTANICAL_GARDENS_CAT = 'gardens'
CABARETS_CAT = 'cabaret'
CASINOS_CAT = 'casinos'
CASTLES_CAT = 'castles'
CHOIRS_CAT = 'choirs'
CINEMAS_CAT = 'movietheaters'
COUNTRY_CLUBS_CAT = 'countryclubs'
CULTURAL_CENTRE_CAT = 'culturalcentre'
FESTIVALS_CAT = 'festivals'
CHRISTMAS_MARKETS_CAT = 'xmasmarkets'
FUN_FAIRS_CAT = 'funfair'
GENERAL_FESTIVALS_CAT = 'generalfestivals'
TRADE_FAIRS_CAT = 'tradefairs'
JAZZ_BLUES_CAT = 'jazzandblues'
MAH_JONG_HALLS_CAT = 'mahjong'
MARCHING_BANDS_CAT = 'marchingbands'
MUSEUMS_CAT = 'museums'
MUSIC_VENUES_CAT = 'musicvenues'
OBSERVATORIES_CAT = 'observatories'
OPERAS_CAT = 'opera'
PACHINKO_CAT = 'pachinko'
PAINT_SIP_CAT = 'paintandsip'
PLANETARIUM_CAT = 'planetarium'
PROFESSIONAL_SPORTS_TEAMS_CAT = 'sportsteams'
PSYCHIC_ASTROLOGERS_CAT = 'psychic_astrology'
RACING_TRACKS_CAT = 'racetracks'
SOCIAL_CLUBS_CAT = 'social_clubs'
STREET_ART_CAT = 'streetart'
TABLAO_FLAMENCO_CAT = 'tablaoflamenco'
THEATRES_CAT = 'theater'
TICKET_SALES_CAT = 'ticketsales'
WINERIES_CAT = 'wineries'
BEAUTY_SPAS_CAT = 'beautysvc'
BARBERS_CAT = 'barbers'
BEAUTY_MAKEUP_CAT = 'cosmetics'
EROTIC_MASSAGE_CAT = 'eroticmassage'
EYELASH_EXTENSION_EYELASH_TINTING_CAT = 'eyelashservice'
HAIR_EXTENSIONS_CAT = 'hair_extensions'
HAIR_LOSS_CENTERS_CAT = 'hairloss'
HAIR_REMOVAL_CAT = 'hairremoval'
LASER_HAIR_REMOVAL_CAT = 'laser_hair_removal'
SUGARING_CAT = 'sugaring'
WAXING_CAT = 'waxing'
HAIRDRESSERS_CAT = 'hair'
BLOW_DRY_SERVICES_CAT = 'blowoutservices'
HAIR_EXTENSIONS_CAT = 'hair_extensions'
HAIR_STYLISTS_CAT = 'hairstylists'
MENS_HAIR_SALONS_CAT = 'menshair'
MAKEUP_ARTISTS_CAT = 'makeupartists'
MASSAGE_CAT = 'massage'
MEDICAL_SPAS_CAT = 'medicalspa'
NAIL_SALONS_CAT = 'othersalons'
PERFUME_CAT = 'perfume'
PERMANENT_MAKEUP_CAT = 'permanentmakeup'
PIERCING_CAT = 'piercing'
ROLFING_CAT = 'rolfing'
SKIN_CARE_CAT = 'skincare'
SPA_CAT = 'spas'
TANNING_CAT = 'tanning'
SPRAY_TAN_CAT = 'spraytanning'
SUNBEDS_CAT = 'tanningbeds'
TATTOO_CAT = 'tattoo'
BICYCLES_CAT = 'bicycles'
BIKE_ASSOCIATIONS_CAT = 'bikeassociations'
BIKE_REPAIR_CAT = 'bikerepair'
BIKE_SHOPS_CAT = 'bikeshop'
SPECIAL_BIKES_CAT = 'specialbikes'
CAR_MOTORCYCLE_CAT = 'auto'
AIRCRAFT_DEALERS_CAT = 'aircraftdealers'
AUTO_CUSTOMIZATION_CAT = 'autocustomization'
AUTO_ELECTRIC_SERVICES_CAT = 'autoelectric'
AUTO_LOAN_PROVIDERS_CAT = 'autoloanproviders'
AUTO_PARTS_SUPPLIES_CAT = 'autopartssupplies'
BOAT_DEALERS_CAT = 'boatdealers'
CAR_BUYERS_CAT = 'carbuyers'
CAR_DEALERS_CAT = 'car_dealers'
CAR_INSPECTORS_CAT = 'autodamageassessment'
CAR_SERVICING_CAT = 'autorepair'
CAR_SHARE_SERVICES_CAT = 'carshares'
CAR_STEREO_INSTALLATIONS_CAT = 'stereo_installation'
CAR_WASH_CAT = 'carwash'
GLASS_TINTING_INSULATION_CAT = 'autoglass'
LP_GAS_CONVERSIONS_CAT = 'oilchange'
MOBILE_DENT_REPAIR_CAT = 'mobiledentrepair'
MOTORBIKE_DEALERS_CAT = 'motorbikedealers'
MOTORBIKE_REPAIR_CAT = 'motorbikerepair'
PANEL_BEATERS_PAINT_SERVICES_CAT = 'Panel'
PARKING_CAT = 'parking'
PETROL_SERVICE_STATIONS_CAT = 'servicestations'
RV_DEALERS_CAT = 'rv_dealers'
RV_REPAIR_CAT = 'rvrepair'
REGISTRATION_SERVICES_CAT = 'registrationservices'
TOWING_ROADSIDE_ASSISTANCE_CAT = 'towing'
TRUCK_HIRE_CAT = 'truck_rental'
TYRES_CAT = 'tyres'
VALETING_CAT = 'auto_detailing'
VEHICLE_SHIPPING_CAT = 'vehicleshipping'
WARRANT_OF_FITNESS_MOTOR_VEHICLE_INSPECTION_CAT = 'motor_vehicle_inspection'
WHEEL_RIM_REPAIR_CAT = 'wheelrimrepair'
WINDSCREEN_INSTALLATION_REPAIR_CAT = 'windshieldinstallrepair'
EDUCATION_CAT = 'education'
ADULT_EDUCATION_CAT = 'adultedu'
AFTER_SCHOOL_CLASSES_CAT = 'tutoring'
ART_CLASSES_CAT = 'artclasses'
COLLEGE_COUNSELING_CAT = 'collegecounseling'
EDUCATIONAL_SERVICES_CAT = 'educationservices'
PRESCHOOLS_CAT = 'preschools'
PRIMARY_SCHOOLS_CAT = 'primaryschools'
PRIVATE_SCHOOLS_CAT = 'privateschools'
PRIVATE_TUTORS_CAT = 'privatetutors'
RELIGIOUS_SCHOOLS_CAT = 'religiousschools'
SECONDARY_SCHOOLS_CAT = 'highschools'
SPECIAL_EDUCATION_CAT = 'specialed'
SPECIALTY_SCHOOLS_CAT = 'specialtyschools'
ART_SCHOOLS_CAT = 'artschools'
BARTENDING_SCHOOLS_CAT = 'bartendingschools'
BEAUTY_SCHOOLS_CAT = 'cosmetology_schools'
CPR_CLASSES_CAT = 'cprclasses'
CIRCUS_SCHOOLS_CAT = 'circusschools'
COOKERY_SCHOOLS_CAT = 'cookingschools'
DANCE_SCHOOLS_CAT = 'dance_schools'
DRIVING_SCHOOLS_CAT = 'driving_schools'
FIREARM_TRAINING_CAT = 'firearmtraining'
FIRST_AID_CLASSES_CAT = 'firstaidclasses'
FLIGHT_INSTRUCTION_CAT = 'flightinstruction'
FOOD_SAFETY_TRAINING_CAT = 'foodsafety'
LANGUAGE_SCHOOLS_CAT = 'language_schools'
MASSAGE_SCHOOLS_CAT = 'massage_schools'
NURSING_SCHOOLS_CAT = 'nursingschools'
PARENTING_CLASSES_CAT = 'parentingclasses'
POLE_DANCING_CLASSES_CAT = 'poledancingclasses'
SAMBA_SCHOOLS_CAT = 'sambaschools'
SKI_SCHOOLS_CAT = 'skischools'
SWIMMING_LESSONS_CAT = 'swimminglessons'
VOCATIONAL_TECHNICAL_SCHOOLS_CAT = 'vocation'
TEST_PREPARATION_CAT = 'testprep'
UNIVERSITY_COLLEGES_CAT = 'collegeuniv'
EVENT_PLANNING_EVENT_SERVICES_CAT = 'eventservices'
BARTENDERS_CAT = 'bartenders'
BOAT_CHARTERS_CAT = 'boatcharters'
CARDS_STATIONERY_CAT = 'stationery'
CATERERS_CAT = 'catering'
CLOWNS_CAT = 'clowns'
DJS_CAT = 'djs'
EVENT_PARTY_PLANNING_CAT = 'eventplanning'
FACE_PAINTING_CAT = 'facepainting'
HOTELS_CAT = 'hotels'
AGRITURISMI_CAT = 'agriturismi'
MOUNTAIN_HUTS_CAT = 'mountainhuts'
PENSIONS_CAT = 'pensions'
RESIDENCES_CAT = 'residences'
REST_STOPS_CAT = 'reststops'
MAGICIANS_CAT = 'magicians'
MOHELS_CAT = 'mohels'
MUSICIANS_CAT = 'musicians'
OFFICIANTS_CAT = 'officiants'
PARTY_BIKE_RENTALS_CAT = 'partybikerentals'
PARTY_BUS_RENTALS_CAT = 'partybusrentals'
PARTY_EQUIPMENT_HIRE_CAT = 'partyequipmentrentals'
PARTY_SUPPLIES_CAT = 'partysupplies'
PERSONAL_CHEFS_CAT = 'personalchefs'
PHOTO_BOOTH_HIRE_CAT = 'photoboothrentals'
PHOTOGRAPHERS_CAT = 'photographers'
EVENT_PHOTOGRAPHY_CAT = 'eventphotography'
SESSION_PHOTOGRAPHY_CAT = 'sessionphotography'
TRIVIA_HOSTS_CAT = 'triviahosts'
VALET_SERVICES_CAT = 'valetservices'
VENUES_EVENT_SPACES_CAT = 'venues'
VIDEOGRAPHER_FILM_MAKERS_CAT = 'videographers'
WEDDING_PLANNERS_CAT = 'wedding_planning'
FINANCIAL_SERVICES_CAT = 'financialservices'
ACCOUNTANT_FINANCIAL_ADVISORS_CAT = 'financialadvising'
BANK_BUILDING_SOCIETIES_CAT = 'banks'
CHEQUE_CASHINGPAYDAY_LOANS_CAT = 'paydayloans'
CURRENCY_EXCHANGE_CAT = 'currencyexchange'
DEBT_RELIEF_SERVICES_CAT = 'debtrelief'
INSURANCE_CAT = 'insurance'
INVESTING_CAT = 'investing'
TAX_SERVICES_CAT = 'taxservices'
FOOD_CAT = 'food'
BAGELS_CAT = 'bagels'
BAKERIES_CAT = 'bakeries'
BEVERAGE_STORES_CAT = 'beverage_stores'
BREWERIES_CAT = 'breweries'
BUBBLE_TEA_CAT = 'bubbletea'
BUTCHERS_CAT = 'butcher'
CSA_CAT = 'csa'
CAKE_SHOP_PATISSERIE_SHOPS_CAT = 'cakeshop'
CHURROS_CAT = 'churros'
COFFEE_TEA_SHOPS_CAT = 'coffee'
COFFEE_TEA_SUPPLIES_CAT = 'coffeeteasupplies'
CUPCAKES_CAT = 'cupcakes'
DIY_FOOD_CAT = 'diyfood'
DAIRY_SUPERETTE_CAT = 'dairy_superette'
DELICATESSEN_CAT = 'delicatessen'
DESSERTS_CAT = 'desserts'
DISTILLERIES_CAT = 'distilleries'
DONAIRS_CAT = 'donairs'
DONUTS_CAT = 'donuts'
ETHNIC_GROCERY_CAT = 'ethicgrocery'
ETHNIC_GROCERY_CAT = 'ethnicgrocery'
FARMERS_MARKET_CAT = 'farmersmarket'
FISHMONGERS_CAT = 'fishmonger'
FOOD_DELIVERY_CAT = 'fooddeliveryservices'
FOOD_TRUCKS_CAT = 'foodtrucks'
FRITERIES_CAT = 'friterie'
GELATO_CAT = 'gelato'
HAWKER_CENTRE_CAT = 'hawkercentre'
HONEY_CAT = 'honey'
ICE_CREAM_GELATO_FROZEN_YOGHURT_CAT = 'icecream'
INTERNET_CAFES_CAT = 'internetcafe'
JAPANESE_SWEETS_CAT = 'jpsweets'
JUICE_BAR_SMOOTHIES_CAT = 'juicebars'
KIOSKS_CAT = 'kiosk'
LIQUOR_STORE_CAT = 'Bottle'
MILKSHAKE_BARS_CAT = 'milkshakebars'
MULLED_WINE_CAT = 'gluhwein'
ORGANIC_SHOPS_CAT = 'organic_stores'
PANZEROTTI_CAT = 'panzerotti'
PARENT_CAFES_CAT = 'eltern_cafes'
PIADINA_CAT = 'piadina'
PRETZELS_CAT = 'pretzels'
SALUMERIES_CAT = 'salumerie'
SHAVED_ICE_CAT = 'shavedice'
SPECIALTY_FOOD_CAT = 'gourmet'
CHEESE_SHOPS_CAT = 'cheese'
CHOCOLATE_CHOCOLATIERS_CAT = 'chocolate'
CONFECTIONARY_CAT = 'candy'
ETHNIC_FOOD_CAT = 'ethnicmarkets'
FRUIT_VEGETABLE_SHOP_CAT = 'markets'
HEALTH_FOOD_CAT = 'healthmarkets'
HERBS_SPICES_CAT = 'herbsandspices'
MEAT_SHOPS_CAT = 'meats'
PASTA_SHOPS_CAT = 'pastashops'
SEAFOOD_SHOPMARKET_CAT = 'seafoodmarkets'
TOFU_SHOPS_CAT = 'tofu'
STREET_FOOD_CAT = 'streetvendors'
SUPERMARKETS_CAT = 'grocery'
TEA_ROOMS_CAT = 'tea'
WINERIES_CAT = 'wineries'
ZAPIEKANKA_CAT = 'zapiekanka'
GOVERNMENT_PUBLIC_SERVICES_CAT = 'publicservicesgovt'
AUTHORIZED_POSTAL_REPRESENTATIVES_CAT = 'authorized_postal_representative'
COMMUNITY_CENTRES_CAT = 'communitycenters'
COURTHOUSES_CAT = 'courthouses'
DVLA_CAT = 'departmentsofmotorvehicles'
EMBASSIES_CAT = 'embassy'
FIRE_DEPARTMENTS_CAT = 'firedepartments'
LANDMARKS_HISTORIC_BUILDINGS_CAT = 'landmarks'
LIBRARIES_CAT = 'libraries'
POLICE_STATIONS_CAT = 'policedepartments'
POST_OFFICES_CAT = 'postoffices'
REGISTRY_OFFICES_CAT = 'registry_office'
TAX_OFFICES_CAT = 'taxoffice'
HEALTH_MEDICAL_CAT = 'health'
AE_CAT = 'urgent_care'
ACUPUNCTURE_CAT = 'acupuncture'
BULK_BILLING_CAT = 'Bulk'
CARE_HOME_NURSING_HOMES_CAT = 'retirement_homes'
CARERS_HOME_HEALTH_CARE_CAT = 'homehealthcare'
CHIROPRACTORS_CAT = 'chiropractors'
DENTAL_HYGIENISTS_CAT = 'dentalhygienists'
MOBILE_CLINICS_CAT = 'dentalhygienistsmobile'
STOREFRONT_CLINICS_CAT = 'dentalhygieniststorefront'
DENTISTS_CAT = 'dentists'
CHILDRENS_DENTISTS_CAT = 'pediatric_dentists'
ENDODONTISTS_CAT = 'endodontists'
GENERAL_DENTISTRY_CAT = 'generaldentistry'
ORAL_SURGEONS_CAT = 'oralsurgeons'
ORTHODONTISTS_CAT = 'orthodontists'
PERIODONTISTS_CAT = 'periodontists'
TEETH_WHITENING_COSMETIC_DENTISTRY_CAT = 'cosmeticdentists'
DIAGNOSTIC_SERVICES_CAT = 'diagnosticservices'
DIAGNOSTIC_IMAGING_CAT = 'diagnosticimaging'
LABORATORY_TESTING_CAT = 'laboratorytesting'
DOCTORS_CAT = 'physicians'
ALLERGISTS_CAT = 'allergist'
ANESTHETISTS_ANESTHESIOLOGISTS_CAT = 'anesthetists_anesthesiologists'
AUDIOLOGISTS_CAT = 'audiologist'
CARDIOLOGISTS_CAT = 'cardiology'
DERMATOLOGISTS_CAT = 'dermatology'
EAR_NOSE_THROAT_CAT = 'earnosethroat'
ENDOCRINOLOGISTS_CAT = 'endocrinologists'
FERTILITY_CLINIC_TREATMENT_CAT = 'fertility'
GP_CAT = 'familydr'
GASTROENTEROLOGISTS_CAT = 'gastroenterologist'
GERONTOLOGISTS_CAT = 'gerontologist'
HOLISTIC_NATUROPATHIC_CAT = 'naturopathic'
INTERNAL_MEDICINE_CAT = 'internalmed'
NEUROLOGISTS_CAT = 'neurologist'
OBSTETRICIAN_GYNOCOLOGISTS_CAT = 'obgyn'
ONCOLOGISTS_CAT = 'oncologist'
OPHTHALMOLOGISTS_CAT = 'opthamalogists'
ORTHOPAEDISTS_CAT = 'orthopedists'
OSTEOPATH_CAT = 'osteopathicphysicians'
PAEDIATRICIANS_CAT = 'pediatricians'
PLASTIC_AESTHETIC_SURGEONS_CAT = 'cosmeticsurgeons'
PODIATRISTS_CAT = 'podiatrists'
PROCTOLOGISTS_CAT = 'proctologist'
PSYCHIATRISTS_CAT = 'psychiatrists'
PULMONOLOGISTS_CAT = 'pulmonologist'
RADIOLOGISTS_CAT = 'radiologists'
RHEUMATOLOGISTS_CAT = 'rhematologists'
SPORTS_MEDICINE_CAT = 'sportsmed'
SURGEONS_CAT = 'surgeons'
TATTOO_REMOVAL_CAT = 'tattooremoval'
UROLOGISTS_CAT = 'urologists'
DOULAS_CAT = 'doulas'
EMERGENCY_ROOMS_CAT = 'emergencyrooms'
HEALTH_INSURANCE_OFFICES_CAT = 'healthinsurance'
HEARING_AID_PROVIDERS_CAT = 'hearingaidproviders'
HEARING_AIDS_CAT = 'hearing_aids'
HOSPICES_CAT = 'hospice'
HOSPITALS_CAT = 'hospitals'
HYPNOSIS_HYPNOTHERAPY_CAT = 'hypnosis'
LACTATION_SERVICES_CAT = 'lactationservices'
LASER_EYE_SURGERY_LASIK_CAT = 'laserlasikeyes'
LICE_SERVICES_CAT = 'liceservices'
MASSAGE_THERAPY_CAT = 'massage_therapy'
MEDICAL_CENTRE_DOCTORS_SURGERY_CAT = 'Medical'
BULK_BILLINGS_CAT = 'bulkbilling'
OSTEOPATHS_CAT = 'osteopaths'
WALKIN_CLINICS_CAT = 'walkinclinics'
MEDICAL_FOOT_CARE_CAT = 'medicalfoot'
MEDICAL_SPAS_CAT = 'medicalspa'
MEDICAL_TRANSPORTATION_CAT = 'medicaltransportation'
MENTAL_HEALTH_COUNSELLING_CAT = 'c_and_mh'
PSYCHOANALYSTS_CAT = 'psychoanalysts'
PSYCHOLOGISTS_CAT = 'psychologists'
PSYCHOTHERAPISTS_CAT = 'psychotherapists'
SEX_THERAPISTS_CAT = 'sextherapists'
SPORTS_PSYCHOLOGISTS_CAT = 'sportspsychologists'
MIDWIVES_CAT = 'midwives'
NURSE_PRACTITIONER_CAT = 'nursepractitioner'
NUTRITIONISTS_CAT = 'nutritionists'
OCCUPATIONAL_THERAPY_CAT = 'occupationaltherapy'
OPTOMETRISTS_CAT = 'optometrists'
ORTHOTICS_CAT = 'orthotics'
PHARMACIES_CAT = 'pharmacy'
PHYSIOTHERAPY_CAT = 'physicaltherapy'
PROSTHETICS_CAT = 'prosthetics'
REFLEXOLOGY_CAT = 'reflexology'
REHABILITATION_CENTERS_CAT = 'rehabilitation_center'
REIKI_CAT = 'reiki'
SAUNAS_CAT = 'saunas'
SLEEP_SPECIALISTS_CAT = 'sleepspecialists'
SPEECH_THERAPY_CAT = 'speech_therapists'
TRADITIONAL_CHINESE_MEDICINE_CAT = 'tcm'
WEIGHT_LOSS_CENTRES_CAT = 'weightlosscenters'
HOME_SERVICES_CAT = 'homeservices'
BUILDERS_CAT = 'contractors'
BUILDING_SUPPLIES_CAT = 'buildingsupplies'
CABINETRY_CAT = 'cabinetry'
CARPENTERS_CAT = 'carpenters'
CARPET_FITTERS_CAT = 'carpeting'
CARPET_INSTALLATION_CAT = 'carpetinstallation'
CHIMNEY_SWEEPS_CAT = 'chimneysweeps'
CLEANER_CLEANING_SERVICES_CAT = 'homecleaning'
CURTAINS_BLINDS_CAT = 'blinds'
DAMAGE_RESTORATION_CAT = 'damagerestoration'
DOOR_SALESINSTALLATION_CAT = 'doorsales'
DRYWALL_INSTALLATION_REPAIR_CAT = 'drywall'
ELECTRICIANS_CAT = 'electricians'
FENCES_GATES_CAT = 'fencesgates'
FIRE_PROTECTION_SERVICES_CAT = 'fireprotection'
FIREPLACE_SERVICES_CAT = 'fireplace'
FIREWOOD_CAT = 'firewood'
FLOORING_TILING_CAT = 'flooring'
FURNITURE_ASSEMBLY_CAT = 'furnitureassembly'
GARAGE_DOOR_SERVICES_CAT = 'garage_door_services'
GARDENERS_CAT = 'gardeners'
GLASS_MIRRORS_CAT = 'glassandmirrors'
GLAZIERS_CAT = 'windowsinstallation'
GUTTER_CLEANING_CAT = 'gutterservices'
HANDYMEN_CAT = 'handyman'
HEATING_AIR_CONDITIONING_CAT = 'hvac'
HOME_AUTOMATION_CAT = 'homeautomation'
HOME_CINEMA_CAT = 'hometheatreinstallation'
HOME_INSPECTION_CAT = 'home_inspectors'
HOME_ORGANIZATION_CAT = 'home_organization'
HOME_WINDOW_TINTING_CAT = 'homewindowtinting'
INSULATION_INSTALLATION_CAT = 'insulationinstallation'
INTERIOR_DESIGN_CAT = 'interiordesign'
INTERNET_SERVICE_PROVIDERS_CAT = 'isps'
IRRIGATION_CAT = 'irrigation'
KEYS_LOCKSMITHS_CAT = 'locksmiths'
LANDSCAPE_GARDENERS_CAT = 'landscapearchitects'
LANDSCAPING_CAT = 'landscaping'
LIGHTING_FIXTURES_EQUIPMENT_CAT = 'lighting'
MASONRYCONCRETE_CAT = 'masonry_concrete'
PAINTER_DECORATORS_CAT = 'painters'
PLUMBING_CAT = 'plumbing'
POOL_HOT_TUB_SERVICES_CAT = 'poolservice'
POOL_CLEANERS_CAT = 'poolcleaners'
PRESSURE_WASHER_CAT = 'pressurewashers'
PROPERTY_CAT = 'realestate'
ART_SPACE_RENTALS_CAT = 'artspacerentals'
COMMERCIAL_REAL_ESTATE_CAT = 'commercialrealestate'
ESTATE_AGENTS_CAT = 'realestateagents'
ESTATE_LIQUIDATION_CAT = 'estateliquidation'
FLATS_CAT = 'apartments'
HOME_STAGING_CAT = 'homestaging'
KITCHEN_INCUBATORS_CAT = 'kitchenincubators'
MOBILE_HOME_DEALERS_CAT = 'mobilehomes'
MORTGAGE_BROKERS_CAT = 'mortgagebrokers'
PROPERTY_MANAGEMENT_CAT = 'propertymgmt'
PROPERTY_SERVICES_CAT = 'realestatesvcs'
SHARED_OFFICE_SPACES_CAT = 'sharedofficespaces'
UNIVERSITY_ACCOMMODATION_CAT = 'university_housing'
REFINISHING_SERVICES_CAT = 'refinishing'
REMOVALS_CAT = 'movers'
ROOFING_CAT = 'roofing'
SECURITY_SYSTEMS_CAT = 'securitysystems'
SHUTTERS_CAT = 'shutters'
SOLAR_INSTALLATION_CAT = 'solarinstallation'
STRUCTURAL_ENGINEERS_CAT = 'structuralengineers'
STUCCO_SERVICES_CAT = 'stucco'
TELEVISION_SERVICE_PROVIDERS_CAT = 'televisionserviceproviders'
TREE_SURGEONS_CAT = 'treeservices'
UTILITIES_CAT = 'utilities'
WATER_PURIFICATION_SERVICES_CAT = 'waterpurification'
WINDOW_CLEANERS_CAT = 'windowwashing'
HOTEL_TRAVEL_CAT = 'hotelstravel'
AIRPORTS_CAT = 'airports'
BBS_CAT = 'bedbreakfast'
CAMPER_VAN_HIRE_CAT = 'rvrental'
CAMPGROUNDS_HOLIDAY_PARKS_CAT = 'campgrounds_holidayparks'
CAR_HIRE_CAT = 'carrental'
GUEST_HOUSES_CAT = 'guesthouses'
HEALTH_SPAS_CAT = 'healthretreats'
HOLIDAY_RENTALS_CAT = 'vacation_rentals'
HOSTELS_CAT = 'hostels'
HOTELS_CAT = 'hotels'
AGRITURISMI_CAT = 'agriturismi'
MOUNTAIN_HUTS_CAT = 'mountainhuts'
PENSIONS_CAT = 'pensions'
RESIDENCES_CAT = 'residences'
REST_STOPS_CAT = 'reststops'
MOTORBIKE_RENTAL_CAT = 'motorbike_rental'
RV_PARKS_CAT = 'rvparks'
RESORTS_CAT = 'resorts'
SKI_RESORTS_CAT = 'skiresorts'
TOURS_CAT = 'tours'
ARCHITECTURAL_TOURS_CAT = 'architecturaltours'
ART_TOURS_CAT = 'arttours'
BUS_TOURS_CAT = 'bustours'
FOOD_TOURS_CAT = 'foodtours'
HISTORICAL_TOURS_CAT = 'historicaltours'
WALKING_TOURS_CAT = 'walkingtours'
WINE_TOURS_CAT = 'winetours'
TRAIN_STATIONS_CAT = 'trainstations'
TRANSPORTATION_CAT = 'transport'
AIRLINES_CAT = 'airlines'
AIRPORT_SHUTTLES_CAT = 'airport_shuttles'
BIKE_SHARING_CAT = 'bikesharing'
BUS_COACHES_CAT = 'buses'
DOLMUS_STATIONS_CAT = 'dolmusstation'
FERRIES_CAT = 'ferries'
LIMOS_CAT = 'limos'
PEDICABS_CAT = 'pedicabs'
PUBLIC_TRANSPORT_CAT = 'publictransport'
TAXI_MINICABS_CAT = 'taxis'
TRAINS_CAT = 'trains'
WATER_TAXIS_CAT = 'watertaxis'
TRAVEL_AGENTS_CAT = 'travelservices'
VACATION_RENTAL_AGENTS_CAT = 'vacationrentalagents'
LOCAL_FLAVOUR_CAT = 'localflavor'
YELP_EVENTS_CAT = 'yelpevents'
LOCAL_SERVICES_CAT = 'localservices'
ADOPTION_SERVICES_CAT = 'adoptionservices'
APPLIANCES_REPAIR_CAT = 'homeappliancerepair'
APPRAISAL_SERVICES_CAT = 'appraisalservices'
BAIL_BONDSMEN_CAT = 'bailbondsmen'
BIKE_REPAIR_MAINTENANCE_CAT = 'bike_repair_maintenance'
BOOKBINDING_CAT = 'bookbinding'
CARPET_CLEANING_CAT = 'carpet_cleaning'
CHILD_CARE_DAY_CARE_CAT = 'childcare'
COBBLER_SHOE_REPAIR_CAT = 'shoerepair'
COMMUNITY_SERVICE_NON_PROFIT_CAT = 'nonprofit'
FOOD_BANKS_CAT = 'foodbanks'
COURIERS_CAT = 'shipping_centers'
COURIERS_DELIVERY_SERVICES_CAT = 'couriers'
DRY_CLEANING_LAUNDRY_SERVICES_CAT = 'drycleaninglaundry'
ELECTRICAL_REPAIRS_CAT = 'electronicsrepair'
FUNERAL_SERVICES_CEMETERIES_CAT = 'funeralservices'
FURNITURE_REPAIR_CAT = 'furniturerepair'
FURNITURE_REUPHOLSTERY_CAT = 'reupholstery'
IT_SERVICES_COMPUTER_LAPTOP_REPAIR_CAT = 'itservices'
DATA_RECOVERY_CAT = 'datarecovery'
MOBILE_PHONE_REPAIR_CAT = 'mobilephonerepair'
TELECOMMUNICATIONS_CAT = 'telecommunications'
INTERNET_BOOTHS_CALLING_CENTERS_CAT = 'internetbooth'
JEWELRY_REPAIR_CAT = 'jewelryrepair'
JUNK_REMOVAL_HAULING_CAT = 'junkremovalandhauling'
KNIFE_SHARPENING_CAT = 'knifesharpening'
MAILBOX_CENTERS_CAT = 'mailboxcenters'
METAL_FABRICATORS_CAT = 'metalfabricators'
MUSICAL_INSTRUMENT_SERVICES_CAT = 'musicinstrumentservices'
GUITAR_STORES_CAT = 'guitarstores'
PIANO_SERVICES_CAT = 'pianoservices'
PIANO_STORES_CAT = 'pianostores'
NANNY_SERVICES_CAT = 'nannys'
NOTARIES_CAT = 'notaries'
PEST_CONTROL_CAT = 'pest_control'
POWDER_COATING_CAT = 'powdercoating'
PRINTING_PHOTOCOPYING_CAT = 'copyshops'
PROPANE_CAT = 'propane'
RECORD_LABELS_CAT = 'record_labels'
RECORDING_REHEARSAL_STUDIOS_CAT = 'recording_studios'
RECYCLING_SCRAP_CENTRES_CAT = 'recyclingcenter'
SCREEN_PRINTING_CAT = 'screenprinting'
SCREEN_PRINTING_TSHIRT_PRINTING_CAT = 'screen_printing_tshirt_printing'
SELF_STORAGE_STORAGE_UNITS_CAT = 'selfstorage'
SEPTIC_SERVICES_CAT = 'septicservices'
SNOW_PLOUGH_SNOW_REMOVAL_CAT = 'snowremoval'
TAILOR_SEWING_ALTERATIONS_CAT = 'sewingalterations'
WATCH_REPAIR_CAT = 'watch_repair'
WATER_DELIVERY_CAT = 'waterdelivery'
YOUTH_CLUBS_CAT = 'youth_club'
MASS_MEDIA_CAT = 'massmedia'
PRINT_MEDIA_PUBLICATIONS_CAT = 'printmedia'
RADIO_STATIONS_CAT = 'radiostations'
TV_STATIONS_CAT = 'televisionstations'
NIGHTLIFE_CAT = 'nightlife'
ADULT_ENTERTAINMENT_CAT = 'adultentertainment'
BARS_CAT = 'bars'
ABSINTHE_BARS_CAT = 'absinthebars'
AIRPORT_LOUNGES_CAT = 'airportlounges'
BEACH_BARS_CAT = 'beachbars'
BEER_BARS_CAT = 'beerbar'
CHAMPAGNE_BARS_CAT = 'champagne_bars'
COCKTAIL_BARS_CAT = 'cocktailbars'
DIVE_BARS_CAT = 'divebars'
GAY_BARS_CAT = 'gaybars'
HOTEL_BARS_CAT = 'hotel_bar'
IRISH_PUBS_CAT = 'irish_pubs'
LOUNGES_CAT = 'lounges'
PUBS_CAT = 'pubs'
SAKE_BARS_CAT = 'sakebars'
SHISHA_BARS_CAT = 'Beer'
SPORTS_BARS_CAT = 'sportsbars'
WINE_BARS_CAT = 'wine_bars'
BEER_GARDENS_CAT = 'beergardens'
CLUBS_CAT = 'danceclubs'
COFFEESHOPS_CAT = 'coffeeshops'
COMEDY_CLUBS_CAT = 'comedyclubs'
COUNTRY_DANCE_HALLS_CAT = 'countrydancehalls'
DANCE_RESTAURANTS_CAT = 'dancerestaurants'
FASIL_MUSIC_CAT = 'fasil'
JAZZ_BLUES_CAT = 'jazzandblues'
KARAOKE_CAT = 'karaoke'
MUSIC_VENUES_CAT = 'musicvenues'
PIANO_BARS_CAT = 'pianobars'
POOL_SNOOKER_HALL_CAT = 'poolhalls'
PETS_CAT = 'pets'
ANIMAL_RESCUE_SHELTERS_CAT = 'animalshelters'
HORSE_BOARDING_CAT = 'horse_boarding'
PET_ADOPTION_CAT = 'petadoption'
PET_SERVICES_CAT = 'petservices'
AQUARIUM_MAINTENANCE_CAT = 'aquariumservices'
DOG_WALKERS_CAT = 'dogwalkers'
KENNELS_PET_SITTING_CAT = 'pet_sitting'
PET_GROOMERS_CAT = 'groomer'
PET_TRAINING_CAT = 'pet_training'
PET_SHOPS_CAT = 'petstore'
VETS_CAT = 'vet'
PROFESSIONAL_SERVICES_CAT = 'professional'
ACCOUNTANTS_CAT = 'accountants'
ADVERTISING_CAT = 'advertising'
ARCHITECTS_CAT = 'architects'
CAREERS_ADVICE_CAT = 'careercounseling'
EDITORIAL_SERVICES_CAT = 'editorialservices'
FILM_VIDEO_PRODUCTION_CAT = 'videofilmproductions'
GRAPHIC_DESIGN_CAT = 'graphicdesign'
HOUSING_LAW_CAT = 'tenantlaw'
INTERNET_SERVICE_PROVIDERS_CAT = 'isps'
JOBCENTRES_CAT = 'employmentagencies'
LEGAL_SERVICES_CAT = 'legalservices'
LIFE_COACHES_CAT = 'lifecoach'
MARINE_SERVICES_CAT = 'boatrepair'
MARKETING_CAT = 'marketing'
MATCHMAKERS_CAT = 'matchmakers'
MUSIC_PRODUCTION_SERVICES_CAT = 'musicproduction'
OFFICE_CLEANING_CAT = 'officecleaning'
PR_CAT = 'publicrelations'
PATENT_LAW_CAT = 'patentlaw'
PAYROLL_SERVICES_CAT = 'payroll'
PERSONAL_ASSISTANTS_CAT = 'personalassistants'
PRIVATE_INVESTIGATORS_CAT = 'privateinvestigation'
SECURITY_SERVICES_CAT = 'security'
SHREDDING_SERVICES_CAT = 'shredding'
SIGNMAKING_CAT = 'signmaking'
SOFTWARE_DEVELOPMENT_CAT = 'softwaredevelopment'
SOLICITORS_LAWYERS_CAT = 'lawyers'
BANKRUPTCY_LAW_CAT = 'bankruptcy'
BUSINESS_LAW_CAT = 'businesslawyers'
CRIMINAL_DEFENSE_LAW_CAT = 'Criminal'
DUI_LAW_CAT = 'duilawyers'
DIVORCE_FAMILY_LAW_CAT = 'divorce'
EMPLOYMENT_LAW_CAT = 'employmentlawyers'
ESTATE_PLANNING_LAW_CAT = 'estateplanning'
GENERAL_LITIGATION_CAT = 'general_litigation'
IP_INTERNET_LAW_CAT = 'iplaw'
IMMIGRATION_LAW_CAT = 'immigrationlawyers'
PERSONAL_INJURY_LAW_CAT = 'personal_injury'
PROPERTY_LAW_CAT = 'realestatelawyers'
TAX_LAW_CAT = 'taxlaw'
TALENT_AGENCIES_CAT = 'talentagencies'
TAXIDERMY_CAT = 'taxidermy'
TRANSLATION_SERVICES_CAT = 'translationservices'
WEB_DESIGN_CAT = 'web_design'
PROPERTY_CAT = 'realestate'
ART_SPACE_RENTALS_CAT = 'artspacerentals'
COMMERCIAL_REAL_ESTATE_CAT = 'commercialrealestate'
ESTATE_AGENTS_CAT = 'realestateagents'
ESTATE_LIQUIDATION_CAT = 'estateliquidation'
FLATS_CAT = 'apartments'
HOME_STAGING_CAT = 'homestaging'
KITCHEN_INCUBATORS_CAT = 'kitchenincubators'
MOBILE_HOME_DEALERS_CAT = 'mobilehomes'
MORTGAGE_BROKERS_CAT = 'mortgagebrokers'
PROPERTY_MANAGEMENT_CAT = 'propertymgmt'
PROPERTY_SERVICES_CAT = 'realestatesvcs'
SHARED_OFFICE_SPACES_CAT = 'sharedofficespaces'
UNIVERSITY_ACCOMMODATION_CAT = 'university_housing'
RELIGIOUS_ORGANISATIONS_CAT = 'religiousorgs'
BUDDHIST_TEMPLES_CAT = 'buddhist_temples'
CHURCHES_CAT = 'churches'
HINDU_TEMPLES_CAT = 'hindu_temples'
MOSQUES_CAT = 'mosques'
SHRINES_CAT = 'shrines'
SYNAGOGUES_CAT = 'synagogues'
RESTAURANTS_CAT = 'restaurants'
AFGHAN_RESTAURANTS_CAT = 'afghani'
AFRICAN_RESTAURANTS_CAT = 'african'
SENEGALESE_RESTAURANTS_CAT = 'senegalese'
SOUTH_AFRICAN_RESTAURANTS_CAT = 'southafrican'
AMERICAN_RESTAURANTS_CAT = 'newamerican'
ARABIC_RESTAURANTS_CAT = 'arabian'
ARAB_PIZZA_CAT = 'arabpizza'
ARGENTINE_RESTAURANTS_CAT = 'argentine'
ARMENIAN_RESTAURANTS_CAT = 'armenian'
ASIAN_FUSION_RESTAURANTS_CAT = 'asianfusion'
ASTURIAN_RESTAURANTS_CAT = 'asturian'
AUSTRALIAN_RESTAURANTS_CAT = 'australian'
AUSTRIAN_RESTAURANTS_CAT = 'austrian'
BBQ_BARBECUE_CAT = 'bbq'
BAGUETTES_CAT = 'baguettes'
BANGLADESHI_RESTAURANTS_CAT = 'bangladeshi'
BASQUE_RESTAURANTS_CAT = 'basque'
BAVARIAN_RESTAURANTS_CAT = 'bavarian'
BEER_GARDENS_CAT = 'beergarden'
BEER_HALLS_CAT = 'beerhall'
BEISL_CAT = 'beisl'
BELGIAN_RESTAURANTS_CAT = 'belgian'
FLEMISH_CAT = 'flemish'
BISTROS_CAT = 'bistros'
BLACK_SEA_CAT = 'blacksea'
BRASSERIE_CAT = 'brasseries'
BRAZILIAN_RESTAURANTS_CAT = 'brazilian'
BRAZILIAN_EMPANADAS_CAT = 'brazilianempanadas'
CENTRAL_BRAZILIAN_RESTAURANTS_CAT = 'centralbrazilian'
NORTHEASTERN_BRAZILIAN_RESTAURANTS_CAT = 'northeasternbrazilian'
NORTHERN_BRAZILIAN_RESTAURANTS_CAT = 'northernbrazilian'
RODIZIOS_CAT = 'rodizios'
BREAKFAST_BRUNCH_CAT = 'breakfast_brunch'
BRITISH_RESTAURANTS_CAT = 'british'
BUFFET_CAT = 'buffets'
BULGARIAN_RESTAURANTS_CAT = 'bulgarian'
BURGERS_CAT = 'burgers'
BURMESE_RESTAURANTS_CAT = 'burmese'
CAFES_CAT = 'cafes'
CAFETERIAS_CAT = 'cafeteria'
CAJUN_CREOLE_RESTAURANTS_CAT = 'cajun'
CAMBODIAN_RESTAURANTS_CAT = 'cambodian'
CANADIAN_RESTAURANTS_CAT = 'newcanadian'
CANTEENS_CAT = 'canteen'
CARIBBEAN_RESTAURANTS_CAT = 'caribbean'
DOMINICAN_RESTAURANTS_CAT = 'dominican'
HAITIAN_RESTAURANTS_CAT = 'haitian'
PUERTO_RICAN_RESTAURANTS_CAT = 'puertorican'
TRINIDADIAN_RESTAURANTS_CAT = 'trinidadian'
CATALAN_RESTAURANTS_CAT = 'catalan'
CHECH_CAT = 'chech'
CHICKEN_SHOP_RESTAURANTS_CAT = 'chickenshop'
CHICKEN_WINGS_CAT = 'Chicken'
CHILEAN_RESTAURANTS_CAT = 'chilean'
CHINESE_RESTAURANTS_CAT = 'chinese'
CANTONESE_RESTAURANTS_CAT = 'cantonese'
CONGEE_RESTAURANTS_CAT = 'congee'
FUZHOU_CAT = 'fuzhou'
HAKKA_CAT = 'hakka'
HENGHWA_CAT = 'henghwa'
HOKKIEN_CAT = 'hokkien'
HUNAN_CAT = 'hunan'
PEKINESE_CAT = 'pekinese'
SHANGHAINESE_CAT = 'shanghainese'
SZECHUAN_RESTAURANTS_CAT = 'szechuan'
TEOCHEW_CAT = 'teochew'
YUM_CHA_CAT = 'dimsum'
COMFORT_FOOD_CAT = 'comfortfood'
CORSICAN_RESTAURANTS_CAT = 'corsican'
CREPES_CAT = 'creperies'
CROATIAN_RESTAURANTS_CAT = 'serbocroatian'
CUBAN_RESTAURANTS_CAT = 'cuban'
CURRY_SAUSAGE_CAT = 'currysausage'
CYPRIOT_RESTAURANTS_CAT = 'cypriot'
CZECH_RESTAURANTS_CAT = 'czech'
CZECHSLOVAKIAN_RESTAURANTS_CAT = 'czechslovakian'
DAIRYSUPERETTE_CAT = 'dairy_superette'
DANISH_RESTAURANTS_CAT = 'danish'
DELIS_CAT = 'delis'
DINERS_CAT = 'diners'
DUMPLINGS_CAT = 'dumplings'
EASTERN_EUROPEAN_RESTAURANTS_CAT = 'eastern_european'
ETHOPIAN_RESTAURANTS_CAT = 'ethiopian'
FILIPINO_RESTAURANTS_CAT = 'filipino'
FISCHBROETCHEN_CAT = 'fischbroetchen'
FISH_CHIPS_CAT = 'fishnchips'
FONDUE_CAT = 'fondue'
FOOD_COURTS_CAT = 'food_court'
FOOD_STANDS_CAT = 'foodstands'
FRENCH_RESTAURANTS_CAT = 'french'
ALSATIAN_CAT = 'alsatian'
AUVERGNAT_CAT = 'auvergnat'
BERRICHON_CAT = 'berrichon'
BOURGUIGNON_CAT = 'bourguignon'
NICOISE_CAT = 'nicois'
PROVENCAL_CAT = 'provencal'
FRENCH_SOUTHWEST_CAT = 'sud_ouest'
GALICIAN_RESTAURANTS_CAT = 'galician'
GASTRO_PUBS_CAT = 'gastropubs'
GEORGIAN_RESTAURANTS_CAT = 'georgian'
GERMAN_RESTAURANTS_CAT = 'german'
BADEN_CAT = 'baden'
EASTERN_GERMAN_CAT = 'easterngerman'
HESSIAN_CAT = 'hessian'
NORTHERN_GERMAN_CAT = 'northerngerman'
PALATINE_CAT = 'palatine'
RHINELANDIAN_CAT = 'rhinelandian'
GIBLETS_CAT = 'giblets'
GLUTEN_FREE_CAT = 'gluten_free'
GREEK_RESTAURANTS_CAT = 'greek'
HALAL_CAT = 'halal'
HAWAIIAN_RESTAURANTS_CAT = 'hawaiian'
HEURIGER_CAT = 'heuriger'
HIMALAYAN_NEPALESE_RESTAURANTS_CAT = 'himalayan'
HONG_KONG_STYLE_CAFE_CAT = 'hkcafe'
HOT_DOGS_CAT = 'hotdog'
HOT_POT_CAT = 'hotpot'
HUNGARIAN_RESTAURANTS_CAT = 'hungarian'
IBERIAN_RESTAURANTS_CAT = 'iberian'
INDIAN_RESTAURANTS_CAT = 'indpak'
INDONESIAN_RESTAURANTS_CAT = 'indonesian'
INTERNATIONAL_RESTAURANTS_CAT = 'international'
IRISH_RESTAURANTS_CAT = 'irish'
ISLAND_PUBS_CAT = 'island_pub'
ISRAELI_RESTAURANTS_CAT = 'israeli'
ITALIAN_RESTAURANTS_CAT = 'italian'
ABRUZZESE_CAT = 'abruzzese'
ALTOATESINE_CAT = 'altoatesine'
APULIAN_CAT = 'apulian'
CALABRIAN_CAT = 'calabrian'
CUCINA_CAMPANA_CAT = 'cucinacampana'
EMILIAN_CAT = 'emilian'
FRIULAN_CAT = 'friulan'
LIGURIAN_CAT = 'ligurian'
LUMBARD_CAT = 'lumbard'
NAPOLETANA_CAT = 'napoletana'
PIEMONTE_CAT = 'piemonte'
ROMAN_CAT = 'roman'
SARDINIAN_CAT = 'sardinian'
SICILIAN_CAT = 'sicilian'
TUSCAN_CAT = 'tuscan'
VENETIAN_CAT = 'venetian'
JAPANESE_RESTAURANTS_CAT = 'japanese'
BLOWFISH_CAT = 'blowfish'
CONVEYOR_BELT_SUSHI_CAT = 'conveyorsushi'
DONBURI_CAT = 'donburi'
GYUDON_CAT = 'gyudon'
OYAKODON_CAT = 'oyakodon'
HAND_ROLLS_CAT = 'handrolls'
HORUMON_CAT = 'horumon'
IZAKAYA_CAT = 'izakaya'
JAPANESE_CURRY_CAT = 'japacurry'
KAISEKI_CAT = 'kaiseki'
KUSHIKATSU_CAT = 'kushikatsu'
ODEN_CAT = 'oden'
OKINAWAN_CAT = 'okinawan'
OKONOMIYAKI_CAT = 'okonomiyaki'
ONIGIRI_CAT = 'onigiri'
RAMEN_CAT = 'ramen'
ROBATAYAKI_CAT = 'robatayaki'
SOBA_CAT = 'soba'
SUKIYAKI_CAT = 'sukiyaki'
TAKOYAKI_CAT = 'takoyaki'
TEMPURA_CAT = 'tempura'
TEPPANYAKI_CAT = 'teppanyaki'
TONKATSU_CAT = 'tonkatsu'
UDON_CAT = 'udon'
UNAGI_CAT = 'unagi'
WESTERN_STYLE_JAPANESE_FOOD_CAT = 'westernjapanese'
YAKINIKU_CAT = 'yakiniku'
YAKITORI_CAT = 'yakitori'
JEWISH_RESTAURANTS_CAT = 'jewish'
KEBAB_CAT = 'kebab'
KOREAN_RESTAURANTS_CAT = 'korean'
KOSHER_CAT = 'kosher'
KURDISH_RESTAURANTS_CAT = 'kurdish'
LAOS_RESTAURANTS_CAT = 'laos'
LAOTIAN_RESTAURANTS_CAT = 'laotian'
LATIN_AMERICAN_RESTAURANTS_CAT = 'latin'
COLOMBIAN_RESTAURANTS_CAT = 'colombian'
SALVADORAN_RESTAURANTS_CAT = 'salvadoran'
VENEZUELAN_RESTAURANTS_CAT = 'venezuelan'
LIVE_RAW_FOOD_CAT = 'raw_food'
LYONNAIS_RESTAURANTS_CAT = 'lyonnais'
MALAYSIAN_RESTAURANTS_CAT = 'malaysian'
MAMAK_CAT = 'mamak'
NYONYA_CAT = 'nyonya'
MEATBALLS_CAT = 'meatballs'
MEDITERRANEAN_RESTAURANTS_CAT = 'mediterranean'
FALAFEL_CAT = 'falafel'
MEXICAN_RESTAURANTS_CAT = 'mexican'
EASTERN_MEXICAN_CAT = 'easternmexican'
JALISCAN_CAT = 'jaliscan'
NORTHERN_MEXICAN_CAT = 'northernmexican'
OAXACAN_CAT = 'oaxacan'
PUEBLAN_CAT = 'pueblan'
TACOS_CAT = 'tacos'
TAMALES_CAT = 'tamales'
YUCATAN_CAT = 'yucatan'
MIDDLE_EASTERN_RESTAURANTS_CAT = 'mideastern'
EGYPTIAN_RESTAURANTS_CAT = 'egyptian'
LEBANESE_RESTAURANTS_CAT = 'lebanese'
MODERN_AUSTRALIAN_RESTAURANTS_CAT = 'modern_australian'
MODERN_EUROPEAN_RESTAURANTS_CAT = 'modern_european'
MONGOLIAN_RESTAURANTS_CAT = 'mongolian'
MOROCCAN_RESTAURANTS_CAT = 'moroccan'
NEW_ZEALAND_RESTAURANTS_CAT = 'newzealand'
NIGHT_FOOD_CAT = 'nightfood'
NORCINERIES_CAT = 'norcinerie'
OPEN_SANDWICHES_CAT = 'opensandwiches'
ORIENTAL_RESTAURANTS_CAT = 'oriental'
PAKISTANI_RESTAURANTS_CAT = 'pakistani'
PARENT_CAFES_CAT = 'eltern_cafes'
PARMA_CAT = 'parma'
PERSIAN_IRANIAN_RESTAURANTS_CAT = 'persian'
PERUVIAN_RESTAURANTS_CAT = 'peruvian'
PITA_CAT = 'pita'
PIZZA_CAT = 'pizza'
POLISH_RESTAURANTS_CAT = 'polish'
PIEROGIS_CAT = 'pierogis'
PORTUGUESE_RESTAURANTS_CAT = 'portuguese'
ALENTEJO_CAT = 'alentejo'
ALGARVE_CAT = 'algarve'
AZORES_CAT = 'azores'
BEIRA_CAT = 'beira'
FADO_HOUSES_CAT = 'fado_houses'
MADEIRA_CAT = 'madeira'
MINHO_CAT = 'minho'
RIBATEJO_CAT = 'ribatejo'
TRASOSMONTES_CAT = 'tras_os_montes'
POTATOES_CAT = 'Potatoes'
POTATOES_CAT = 'potatoes'
POUTINERIES_CAT = 'poutineries'
PUB_FOOD_CAT = 'pubfood'
RICE_CAT = 'riceshop'
ROMANIAN_CAT = 'romanian'
ROTISSERIE_CHICKEN_CAT = 'rotisserie_chicken'
RUMANIAN_CAT = 'rumanian'
RUSSIAN_RESTAURANTS_CAT = 'russian'
SALAD_CAT = 'salad'
SANDWICHES_CAT = 'sandwiches'
SCANDINAVIAN_RESTAURANTS_CAT = 'scandinavian'
SCOTTISH_RESTAURANTS_CAT = 'scottish'
SEAFOOD_RESTAURANTS_CAT = 'seafood'
SIGNATURE_CUISINE_CAT = 'signature_cuisine'
SINGAPOREAN_RESTAURANTS_CAT = 'singaporean'
SLOVAKIAN_RESTAURANTS_CAT = 'slovakian'
SOUL_FOOD_CAT = 'soulfood'
SOUP_CAT = 'soup'
SOUTHERN_AMERICAN_RESTAURANTS_CAT = 'southern'
SPANISH_RESTAURANTS_CAT = 'spanish'
ARROCERIA_PAELLA_CAT = 'arroceria_paella'
SRI_LANKAN_CAT = 'srilankan'
STEAKHOUSES_CAT = 'steak'
SUSHI_CAT = 'sushi'
SWABIAN_CAT = 'swabian'
SWEDISH_RESTAURANTS_CAT = 'swedish'
SWISS_FOOD_CAT = 'swissfood'
TABERNAS_CAT = 'tabernas'
TAIWANESE_RESTAURANTS_CAT = 'taiwanese'
TAKEAWAY_FAST_FOOD_CAT = 'hotdogs'
TAPAS_SMALL_PLATES_CAT = 'tapasmallplates'
TAPAS_BARS_CAT = 'tapas'
TEX_MEX_RESTAURANTS_CAT = 'tex'
THAI_RESTAURANTS_CAT = 'thai'
TRADITIONAL_AMERICAN_RESTAURANTS_CAT = 'tradamerican'
TRADITIONAL_NORWEGIAN_CAT = 'norwegian'
TRADITIONAL_SWEDISH_CAT = 'traditional_swedish'
TRATTORIE_CAT = 'trattorie'
TURKISH_RESTAURANTS_CAT = 'turkish'
CHEE_KUFTA_CAT = 'cheekufta'
GOZLEME_CAT = 'gozleme'
TURKISH_RAVIOLI_CAT = 'turkishravioli'
UKRANIAN_RESTAURANTS_CAT = 'ukrainian'
UZBEK_CAT = 'uzbek'
VEGAN_RESTAURANTS_CAT = 'vegan'
VEGETARIAN_RESTAURANTS_CAT = 'vegetarian'
VENISON_CAT = 'venison'
VIETNAMESE_RESTAURANTS_CAT = 'vietnamese'
WOK_CAT = 'wok'
WRAPS_CAT = 'wraps'
YUGOSLAV_CAT = 'yugoslav'
SHOPPING_CAT = 'shopping'
ADULT_CAT = 'adult'
ANTIQUES_CAT = 'antiques'
ART_GALLERIES_CAT = 'galleries'
ARTS_CRAFTS_CAT = 'artsandcrafts'
FABRIC_STORES_CAT = 'fabricstores'
ART_SUPPLIES_CAT = 'artsupplies'
CARDS_STATIONERY_CAT = 'stationery'
COOKING_CLASSES_CAT = 'cookingclasses'
EMBROIDERY_CROCHET_CAT = 'embroideryandcrochet'
FANCY_DRESS_CAT = 'costumes'
PICTURE_FRAMING_CAT = 'framing'
AUCTION_HOUSES_CAT = 'auctionhouses'
BABY_ACCESSORIES_FURNITURE_CAT = 'baby_gear'
BARGAIN_SHOPS_CAT = 'discountstore'
BATTERY_STORES_CAT = 'batterystores'
BEAUTY_MAKEUP_CAT = 'cosmetics'
BESPOKE_CLOTHING_CAT = 'bespoke'
BREWING_SUPPLIES_CAT = 'brewingsupplies'
BRIDAL_CAT = 'bridal'
CAMERA_SHOPS_CAT = 'photographystores'
CHINESE_BAZAARS_CAT = 'chinesebazaar'
COMPUTERS_CAT = 'computers'
CONCEPT_STORES_CAT = 'concept_shops'
CUSTOMISED_MERCHANDISE_CAT = 'custommerchandise'
DEPARTMENT_STORES_CAT = 'deptstores'
E_CIGARETTE_CAT = 'vapeshops'
ELECTRONICS_CAT = 'electronics'
EYEWEAR_OPTICIANS_CAT = 'opticians'
FASHION_CAT = 'fashion'
ACCESSORIES_CAT = 'accessories'
CHILDRENS_CLOTHING_CAT = 'childcloth'
DEPARTMENT_STORES_CAT = 'deptstores'
FORMAL_WEAR_CAT = 'formalwear'
HATS_CAT = 'hats'
KIMONOS_CAT = 'kimonos'
LEATHER_SHOPS_CAT = 'leather'
LINGERIE_CAT = 'lingerie'
MATERNITY_WEAR_CAT = 'maternity'
MENS_CLOTHING_CAT = 'menscloth'
PLUS_SIZE_FASHION_CAT = 'plus_size_fashion'
SHOE_SHOPS_CAT = 'shoes'
SLEEPWEAR_CAT = 'sleepwear'
SPORTS_WEAR_CAT = 'sportswear'
STOCKINGS_CAT = 'stockings'
SURF_SHOPS_CAT = 'surfshop'
SWIMWEAR_CAT = 'swimwear'
VINTAGE_SECOND_HAND_CAT = 'vintage'
WOMENS_CLOTHING_CAT = 'womenscloth'
FIREWORKS_CAT = 'fireworks'
FITNESS_EXERCISE_EQUIPMENT_CAT = 'fitnessequipment'
FLEA_MARKETS_CAT = 'fleamarkets'
FLOWERS_GIFTS_CAT = 'flowers'
CARDS_STATIONERY_CAT = 'stationery'
FLORISTS_CAT = 'florists'
FLOWERS_CAT = 'flowersonly'
GIFT_SHOPS_CAT = 'giftshops'
GOLD_BUYERS_CAT = 'goldbuyers'
GOLF_SHOPS_CAT = 'golfshops'
GUNS_AMMO_CAT = 'guns_and_ammo'
HIGH_FIDELITY_AUDIO_EQUIPMENT_CAT = 'hifi'
HOBBY_SHOPS_CAT = 'hobbyshops'
HOME_GARDEN_CAT = 'homeandgarden'
APPLIANCES_CAT = 'appliances'
BED_SHOPS_CAT = 'mattresses'
CHRISTMAS_TREES_CAT = 'christmastrees'
FURNITURE_SHOPS_CAT = 'furniture'
GARDENING_CENTRES_CAT = 'gardening'
HARDWARE_STORES_CAT = 'hardware'
HOME_DECOR_CAT = 'homedecor'
KITCHEN_BATH_CAT = 'kitchenandbath'
LINENS_CAT = 'linens'
MATERIALE_ELETTRICO_CAT = 'materialeelettrico'
PUMPKIN_PATCHES_CAT = 'pumpkinpatches'
RUGS_CAT = 'rugs'
SPA_POOL_CAT = 'spaandpool'
TABLEWARE_CAT = 'tableware'
HORSE_EQUIPMENT_SHOPS_CAT = 'horsequipment'
JEWELLERY_CAT = 'jewelry'
KIOSKS_CAT = 'kiosk'
KNITTING_SHOPS_CAT = 'knittingsupplies'
LUGGAGE_CAT = 'luggage'
MARKET_STALLS_CAT = 'marketstalls'
MEDICAL_SUPPLIES_CAT = 'medicalsupplies'
MOBILE_PHONES_CAT = 'mobilephones'
MOTORBIKE_GEAR_CAT = 'motorcyclinggear'
MUSIC_VIDEO_BOOKS_MAGAZINES_CAT = 'media'
BOOKSHOPS_CAT = 'bookstores'
COMICS_CAT = 'comicbooks'
MUSIC_DVD_CAT = 'musicvideo'
NEWSAGENTS_CAT = 'mags'
VIDEO_GAME_STORES_CAT = 'videogamestores'
VIDEOS_VIDEO_GAME_RENTALS_CAT = 'Video'
VINYL_RECORDS_CAT = 'vinyl_records'
MUSICAL_INSTRUMENTS_TEACHERS_CAT = 'musicalinstrumentsandteachers'
OFFICE_EQUIPMENT_CAT = 'officeequipment'
OPPORTUNITY_SHOPTHRIFT_STORE_CAT = 'thrift_stores'
OUTLET_STORES_CAT = 'outlet_stores'
PAWN_SHOPS_CAT = 'pawn'
PERFUME_CAT = 'perfume'
PERSONAL_SHOPPER_CAT = 'personal_shopping'
PHARMACY_CHEMISTS_CAT = 'drugstores'
POOL_BILLIARDS_CAT = 'poolbilliards'
POP_UP_SHOPS_CAT = 'popupshops'
SCANDINAVIAN_DESIGN_CAT = 'scandinaviandesign'
SHOPPING_CENTERS_CAT = 'shoppingcenters'
SOUVENIR_SHOPS_CAT = 'souvenirs'
SPIRITUAL_SHOPS_CAT = 'spiritual_shop'
SPORTING_GOODS_CAT = 'sportgoods'
BIKES_CAT = 'bikes'
GOLF_EQUIPMENT_CAT = 'golfequipment'
OUTDOOR_GEAR_CAT = 'outdoorgear'
SKATE_SHOPS_CAT = 'skateshops'
SKI_SNOWBOARD_SHOPS_CAT = 'skishops'
SPORTS_WEAR_CAT = 'sportswear'
TICKETS_CAT = 'tickets'
TOBACCONISTS_CAT = 'tobaccoshops'
TOY_SHOPS_CAT = 'toys'
TROPHY_SHOPS_CAT = 'trophyshops'
UNIFORMS_CAT = 'uniforms'
USED_BOOKSTORES_CAT = 'usedbooks'
WATCHES_CAT = 'watches'
WHOLESALE_CAT = 'wholesale_stores'
WIGS_CAT = 'wigs'
SPORTS_LEISURE_CAT = 'active'
ATV_RENTALSTOURS_CAT = 'atvrentals'
AMATEUR_SPORTS_TEAMS_CAT = 'amateursportsteams'
AQUARIUMS_CAT = 'aquariums'
ARCHERY_CAT = 'archery'
BADMINTON_CAT = 'badminton'
BASKETBALL_COURTS_CAT = 'basketballcourts'
BATHING_AREAS_CAT = 'bathing_area'
BATTING_CAGES_CAT = 'battingcages'
BEACH_VOLLEYBALL_CAT = 'beachvolleyball'
BEACHES_CAT = 'beaches'
BICYCLE_PATHS_CAT = 'bicyclepaths'
BIKE_HIRE_CAT = 'bikerentals'
BOATING_CAT = 'boating'
BUNGEE_JUMPING_CAT = 'bungeejumping'
CHALLENGE_COURSES_CAT = 'challengecourses'
CLIMBING_CAT = 'climbing'
DAY_CAMPS_CAT = 'daycamps'
DISC_GOLF_CAT = 'discgolf'
DIVING_CAT = 'diving'
FREE_DIVING_CAT = 'freediving'
SCUBA_DIVING_CAT = 'scuba'
EXPERIENCES_CAT = 'experiences'
FENCING_CAT = 'fencing'
FISHING_CAT = 'fishing'
FITNESS_INSTRUCTION_CAT = 'fitness'
BARRE_CLASSES_CAT = 'barreclasses'
BOOT_CAMPS_CAT = 'bootcamps'
BOXING_CAT = 'boxing'
DANCE_STUDIOS_CAT = 'dancestudio'
GYMS_CAT = 'gyms'
MARTIAL_ARTS_CAT = 'martialarts'
MEDITATION_CENTRES_CAT = 'meditationcenters'
PERSONAL_TRAINERS_CAT = 'healthtrainers'
PILATES_CAT = 'pilates'
SWIMMING_LESSONS_CAT = 'swimminglessons'
TAI_CHI_CAT = 'taichi'
YOGA_CAT = 'yoga'
FLYBOARDING_CAT = 'flyboarding'
FOOTBALL_CAT = 'football'
GLIDING_CAT = 'gliding'
GO_KARTING_CAT = 'gokarts'
GOLF_CAT = 'golf'
GUN_RIFLE_RANGE_CAT = 'gun_ranges'
GYMNASTICS_CAT = 'gymnastics'
HANG_GLIDING_CAT = 'hanggliding'
HORSE_RACING_CAT = 'horseracing'
HOT_AIR_BALLOON_CAT = 'hot_air_balloons'
ICE_RINKS_CAT = 'skatingrinks'
INDOOR_PLAYCENTRES_CAT = 'indoor_playcenter'
JET_SKIS_CAT = 'jetskis'
KIDS_ACTIVITIES_CAT = 'kids_activities'
KITEBOARDING_CAT = 'kiteboarding'
LAKES_CAT = 'lakes'
LASER_TAG_CAT = 'lasertag'
LAWN_BOWLING_CAT = 'lawn_bowling'
LEISURE_CENTRES_CAT = 'leisure_centers'
MINI_GOLF_CAT = 'mini_golf'
MOUNTAIN_BIKING_CAT = 'mountainbiking'
NUDIST_CAT = 'nudist'
PADDLEBOARDING_CAT = 'paddleboarding'
PAINTBALL_CAT = 'paintball'
PARK_FORESTS_CAT = 'parks'
DOG_PARKS_CAT = 'dog_parks'
SKATE_PARKS_CAT = 'skate_parks'
PLAYGROUNDS_CAT = 'playgrounds'
PUBLIC_PLAZAS_CAT = 'publicplazas'
RAFTING_KAYAKING_CAT = 'rafting'
RECREATION_CENTRE_CAT = 'recreation'
ROCK_CLIMBING_CAT = 'rock_climbing'
SAILING_CAT = 'sailing'
SCHOOL_CAMPS_CAT = 'school_camps'
SKIING_CAT = 'skiing'
SKYDIVING_CAT = 'skydiving'
SLEDDING_CAT = 'sledding'
SPIN_CLASSES_CAT = 'spinclasses'
SPIN_CLASSES_CAT = 'cyclingclasses'
SPORT_EQUIPMENT_HIRE_CAT = 'sport_equipment_hire'
SPORTS_CLUBS_CAT = 'sports_clubs'
SQUASH_CAT = 'squash'
STABLES_HORSE_RIDING_CAT = 'horsebackriding'
SURF_LIFESAVING_CAT = 'surflifesaving'
SURFING_CAT = 'surfing'
SWIMMING_POOLS_CAT = 'swimmingpools'
TEN_PIN_BOWLING_CAT = 'bowling'
TENNIS_CAT = 'tennis'
THEME_PARKS_CAT = 'amusementparks'
TRAMPING_CAT = 'tramping'
TRAMPOLINE_PARKS_CAT = 'trampoline'
TUBING_CAT = 'tubing'
VOLLEYBALL_CAT = 'volleyball'
WILDLIFE_HUNTING_RANGES_CAT = 'wildlifehunting'
ZOOS_CAT = 'zoos'
ZORBING_CAT = 'zorbing'

# %%
one
# Out:
# 'Arts & Entertainment (arts, All)\n'

# %%
import string
whitelist = string.letters + string.digits + ' '
new_s = ''.join(c for c in one if c in whitelist)

# %%
new_s
# Out:
# 'Arts  Entertainment arts All'

# %%
import re

# %%
name, code = re.search(r'(.*) \((\w*)', one).groups()

# %%
name = '_'.join(''.join(c.upper() for c in name if c in whitelist).split())

# %%
# Out:
# 'ARTS_ENTERTAINMENT'

# %%
# Out:
# []
